# %%
import os

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "app.settings")
os.environ.setdefault("DATABASE_URL", 
"postgres://localhost:5432/db")

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

import django
django.setup()

from django.db.models import Avg

# %%
from django.db.models import Model

# %%
from main.models import Carrera, Universidad, Orientacion, Formulario, Especifica

# %%
career = Carrera.objects.all()[3]

# %%
stats = Formulario.objects.filter(carrera=career.id)

# %%
stats.aggregate( Count('recomendacion'), Avg('recomendacion'), Avg('profesores'), Avg('exigencia'), Avg('cargaHoraria'), Avg('progIntercambio'))
# Out:
# {'recomendacion__count': 6,
#  'recomendacion__avg': 3.5,
#  'profesores__avg': 2.8333333333333335,
#  'exigencia__avg': 3.8333333333333335,
#  'cargaHoraria__avg': 2.1666666666666665,
#  'progIntercambio__avg': 2.6666666666666665}

# %%
Formulario.objects.filter(carrera=career.id).aggregate(Avg('recomendacion'))
# Out:
# {'recomendacion__avg': 4.0}
